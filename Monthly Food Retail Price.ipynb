# %% [markdown]
# # Import coding :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Monthly_Food_Retail_Prices.csv.zip")
df
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail Price
# 0           Food  JAN-2001          24.0
# 1           Food  JAN-2001          26.0
# ...

# %% [markdown]
# # Analysis Data :

# %%
for i in df.columns:
    print("Column Nam",i,"\n",df[i].value_counts())
# Out:
# Column Nam State
#  Uttar Pradesh        82377
# Tamil Nadu           82377
# Madhya Pradesh       81891
# Rajasthan            69012
# Maharashtra          67554
# West Bengal          67068
# Karnataka            54918
# Andhra Pradesh       54675
# Gujarat              53946
# Assam                52974
# Bihar                51516
# Union Territories    44469
# Kerala               40824
# Punjab               40095
# Orissa               39366
# Uttarakhand          27216
# Jammu Kashmir        26487
# Haryana              26487
# Jharkhand            26001
# Himachal Pradesh     24786
# Nagaland             13851
# Goa                  13851
# Sikkim               13851
# Telangana            13851
# National Capital     13608
# Meghalaya            13608
# Arunachal Pradesh    13122
# Tripura              12879
# Mizoram              12636
# Manipur              12150
# Name: State, dtype: int64
# Column Nam Centre
#  Pune          13851
# Hyderabad     13851
# ...

# %%
df.isnull().sum()
# Out:
# State                0
# Centre               0
# Commodity         9720
# Variety         205578
# Unit                 0
# Category             0
# Date                 0
# Retail Price    568921
# dtype: int64

# %% [markdown]
# # Data Overview :

# %%
df.describe()
# Out:
#         Retail Price
# count  578525.000000
# mean       79.691448
# std       148.780859
# min         0.500000
# 25%        18.000000
# 50%        35.000000
# 75%        80.000000
# max     20045.000000

# %%
df["Commodity"].fillna("Not Available",inplace=True)
df["Variety"].fillna("FAQ",inplace = True)

# %%
df.isna().sum()
# Out:
# State                0
# Centre               0
# Commodity            0
# Variety              0
# Unit                 0
# Category             0
# Date                 0
# Retail Price    568921
# dtype: int64

# %%
df["State"].value_counts()
# Out:
# Uttar Pradesh        82377
# Tamil Nadu           82377
# Madhya Pradesh       81891
# Rajasthan            69012
# Maharashtra          67554
# West Bengal          67068
# Karnataka            54918
# Andhra Pradesh       54675
# Gujarat              53946
# Assam                52974
# Bihar                51516
# Union Territories    44469
# Kerala               40824
# Punjab               40095
# Orissa               39366
# Uttarakhand          27216
# Jammu Kashmir        26487
# Haryana              26487
# Jharkhand            26001
# Himachal Pradesh     24786
# Nagaland             13851
# Goa                  13851
# Sikkim               13851
# Telangana            13851
# National Capital     13608
# Meghalaya            13608
# Arunachal Pradesh    13122
# Tripura              12879
# Mizoram              12636
# Manipur              12150
# Name: State, dtype: int64

# %%
df.dtypes
# Out:
# State            object
# Centre           object
# Commodity        object
# Variety          object
# Unit             object
# Category         object
# Date             object
# Retail Price    float64
# dtype: object

# %%
#exploratory data analysis (EDA process):
checking structure of data
missing values
data trasformation
statistical analysis
# Out:
#   File "C:\Users\kk\AppData\Local\Temp/ipykernel_8764/3614157183.py", line 2
#     checking structure of data
#              ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1147446 entries, 0 to 1147445
# Data columns (total 8 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   State         1147446 non-null  object
#  1   Centre        1147446 non-null  object
#  2   Commodity     1147446 non-null  object
#  3   Variety       1147446 non-null  object
#  4   Unit          1147446 non-null  object
#  5   Category      1147446 non-null  object
#  6   Date          1147446 non-null  object
#  7   Retail Price  578525 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 70.0+ MB

# %% [markdown]
# # function to check missing values :

# %%
df.isna()
# Out:
#          State  Centre  Commodity  Variety   Unit  Category   Date  \
# 0        False   False      False    False  False     False  False
# 1        False   False      False    False  False     False  False
# 2        False   False      False    False  False     False  False
# 3        False   False      False    False  False     False  False
# 4        False   False      False    False  False     False  False
# ...        ...     ...        ...      ...    ...       ...    ...
# 1147441  False   False      False    False  False     False  False
# 1147442  False   False      False    False  False     False  False
# 1147443  False   False      False    False  False     False  False
# 1147444  False   False      False    False  False     False  False
# 1147445  False   False      False    False  False     False  False
#
#          Retail Price
# 0               False
# 1               False
# 2               False
# 3                True
# 4                True
# ...

# %%
df.isnull()
# Out:
#          State  Centre  Commodity  Variety   Unit  Category   Date  \
# 0        False   False      False    False  False     False  False
# 1        False   False      False    False  False     False  False
# 2        False   False      False    False  False     False  False
# 3        False   False      False    False  False     False  False
# 4        False   False      False    False  False     False  False
# ...        ...     ...        ...      ...    ...       ...    ...
# 1147441  False   False      False    False  False     False  False
# 1147442  False   False      False    False  False     False  False
# 1147443  False   False      False    False  False     False  False
# 1147444  False   False      False    False  False     False  False
# 1147445  False   False      False    False  False     False  False
#
#          Retail Price
# 0               False
# 1               False
# 2               False
# 3                True
# 4                True
# ...

# %% [markdown]
# # count of missing values of according to each column :

# %%
df.isna().sum()
# Out:
# State                0
# Centre               0
# Commodity            0
# Variety              0
# Unit                 0
# Category             0
# Date                 0
# Retail Price    568921
# dtype: int64

# %%
df.isna().count()
# Out:
# State           1147446
# Centre          1147446
# Commodity       1147446
# Variety         1147446
# Unit            1147446
# Category        1147446
# Date            1147446
# Retail Price    1147446
# dtype: int64

# %%
df.dropna()
# Out:
#                   State    Centre Commodity     Variety Unit Category  \
# 0        Andhra Pradesh  Chittoor     Moong       Split  Kg.     Food
# 1        Andhra Pradesh    Guntur     Moong       Split  Kg.     Food
# 2        Andhra Pradesh   Kurnool     Moong       Split  Kg.     Food
# 10                Bihar   Hajipur     Moong       Split  Kg.     Food
# 12                Bihar     Patna     Moong       Split  Kg.     Food
# ...                 ...       ...       ...         ...  ...      ...
# 1147436     West Bengal   Asansol     Wheat        Desi  Kg.     Food
# 1147437     West Bengal   Asansol     Wheat  Kalyan HYV  Kg.     Food
# 1147438     West Bengal    Howrah     Wheat        Desi  Kg.     Food
# 1147439     West Bengal    Howrah     Wheat  Kalyan HYV  Kg.     Food
# 1147444     West Bengal     Malda     Wheat        Desi  Kg.     Food
#
#              Date  Retail Price
# 0        JAN-2001          24.0
# 1        JAN-2001          26.0
# ...

# %%
df
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail Price
# 0           Food  JAN-2001          24.0
# 1           Food  JAN-2001          26.0
# ...

# %%
df.fillna(0,inplace=True)

# %%
df.isna().sum()
# Out:
# State           0
# Centre          0
# Commodity       0
# Variety         0
# Unit            0
# Category        0
# Date            0
# Retail Price    0
# dtype: int64

# %%
df
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail Price
# 0           Food  JAN-2001          24.0
# 1           Food  JAN-2001          26.0
# ...

# %% [markdown]
# # Extract First 50 Records :

# %%
df.head(50)
# Out:
#                 State          Centre Commodity Variety Unit Category  \
# 0      Andhra Pradesh        Chittoor     Moong   Split  Kg.     Food
# 1      Andhra Pradesh          Guntur     Moong   Split  Kg.     Food
# 2      Andhra Pradesh         Kurnool     Moong   Split  Kg.     Food
# 3      Andhra Pradesh  Vishakhapatnam     Moong   Split  Kg.     Food
# 4   Arunachal Pradesh        Itanagar     Moong   Split  Kg.     Food
# 5               Assam       Dibrugarh     Moong   Split  Kg.     Food
# 6               Assam          Dispur     Moong   Split  Kg.     Food
# 7               Assam        Guwahati     Moong   Split  Kg.     Food
# 8               Assam         Silchar     Moong   Split  Kg.     Food
# 9               Bihar            Gaya     Moong   Split  Kg.     Food
# 10              Bihar         Hajipur     Moong   Split  Kg.     Food
# 11              Bihar     Muzaffarpur     Moong   Split  Kg.     Food
# ...

# %%
df.iloc[5:50]
# Out:
#                State        Centre Commodity Variety Unit Category      Date  \
# 5              Assam     Dibrugarh     Moong   Split  Kg.     Food  JAN-2001
# 6              Assam        Dispur     Moong   Split  Kg.     Food  JAN-2001
# 7              Assam      Guwahati     Moong   Split  Kg.     Food  JAN-2001
# 8              Assam       Silchar     Moong   Split  Kg.     Food  JAN-2001
# 9              Bihar          Gaya     Moong   Split  Kg.     Food  JAN-2001
# 10             Bihar       Hajipur     Moong   Split  Kg.     Food  JAN-2001
# 11             Bihar   Muzaffarpur     Moong   Split  Kg.     Food  JAN-2001
# 12             Bihar         Patna     Moong   Split  Kg.     Food  JAN-2001
# 13               Goa        Panaji     Moong   Split  Kg.     Food  JAN-2001
# 14           Gujarat  Gandhi Nagar     Moong   Split  Kg.     Food  JAN-2001
# 15           Gujarat        Rajkot     Moong   Split  Kg.     Food  JAN-2001
# ...

# %%
df.tail() # tail function extract last 5 data
# Out:
#                State      Centre Commodity     Variety Unit Category  \
# 1147441  West Bengal  Jalpaiguri     Wheat  Kalyan HYV  Kg.     Food
# 1147442  West Bengal     Kolkata     Wheat        Desi  Kg.     Food
# 1147443  West Bengal     Kolkata     Wheat  Kalyan HYV  Kg.     Food
# 1147444  West Bengal       Malda     Wheat        Desi  Kg.     Food
# 1147445  West Bengal       Malda     Wheat  Kalyan HYV  Kg.     Food
#
#              Date  Retail Price
# 1147441  MAR-2021           0.0
# 1147442  MAR-2021           0.0
# 1147443  MAR-2021           0.0
# 1147444  MAR-2021          20.0
# 1147445  MAR-2021           0.0

# %%
df.columns
# Out:
# Index(['State', 'Centre', 'Commodity', 'Variety', 'Unit', 'Category', 'Date',
#        'Retail Price'],
#       dtype='object')

# %% [markdown]
# # no. of unique values present for the dataset :

# %%
df.nunique()
# Out:
# State             30
# Centre            86
# Commodity         47
# Variety           30
# Unit              11
# Category           1
# Date             243
# Retail Price    1703
# dtype: int64

# %%
#to delete with a given range of rows
df.drop(df.index[10:20],inplace=True)

# %%
df.columns
# Out:
# Index(['State', 'Centre', 'Commodity', 'Variety', 'Unit', 'Category', 'Date',
#        'Retail Price'],
#       dtype='object')

# %%
#statistical operations on dataset
df
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail Price
# 0           Food  JAN-2001          24.0
# 1           Food  JAN-2001          26.0
# ...

# %%
import statistics

# %%
dir(statistics)
# Out:
# ['Counter',
#  'Decimal',
#  'Fraction',
#  'NormalDist',
#  'StatisticsError',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_coerce',
#  '_convert',
#  '_exact_ratio',
#  '_fail_neg',
#  '_find_lteq',
#  '_find_rteq',
#  '_isfinite',
#  '_normal_dist_inv_cdf',
#  '_ss',
#  '_sum',
#  'bisect_left',
#  'bisect_right',
#  'erf',
#  'exp',
#  'fabs',
#  'fmean',
#  'fsum',
#  'geometric_mean',
#  'groupby',
#  'harmonic_mean',
#  'hypot',
#  'itemgetter',
#  'log',
#  'math',
#  'mean',
#  'median',
#  'median_grouped',
#  'median_high',
#  'median_low',
#  'mode',
#  'multimode',
#  'numbers',
#  'pstdev',
#  'pvariance',
#  'quantiles',
#  'random',
#  'sqrt',
#  'stdev',
#  'tau',
#  'variance']

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
# ...

# %%
#describe() function will give you summary statistics of data
df.describe()
# Out:
#        Retail Price
# count  1.147436e+06
# mean   4.017944e+01
# std    1.129078e+02
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    4.000000e+00
# 75%    3.500000e+01
# max    2.004500e+04

# %%
#how to deal with duplicate values
duplicated()
drop_duplicates() #delete the duplicate values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8764/3258517728.py in <module>
#       1 #how to deal with duplicate values
# ----> 2 duplicated()
#       3 drop_duplicates() #delete the duplicate values
#
# NameError: name 'duplicated' is not defined

# %%
df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1147441    False
# 1147442    False
# 1147443    False
# 1147444    False
# 1147445    False
# Length: 1147436, dtype: bool

# %%
df.drop_duplicates()
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail Price
# 0           Food  JAN-2001          24.0
# 1           Food  JAN-2001          26.0
# ...

# %%
#return the statements that your data is contaning duplicate values
df.duplicated().any()
# Out:
# True

# %%
df.duplicated().all()
# Out:
# False

# %%
df.dtypes
# Out:
# State            object
# Centre           object
# Commodity        object
# Variety          object
# Unit             object
# Category         object
# Date             object
# Retail Price    float64
# dtype: object

# %% [markdown]
# # Predicting the Retail Prices:

# %%
df_test = df[df["Retail Price"].isnull()==True]

# %%
df_train = df.dropna()
df_train
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail Price
# 0           Food  JAN-2001          24.0
# 1           Food  JAN-2001          26.0
# ...

# %% [markdown]
# # Data Transformation:

# %%
df[["Month","Year"]] = df['Date'].str.split('-',n=1,expand=True)

# %%
def split_Date(val):
    mon={'JAN':1, 'FEB':2, 'MAR':3, 'APR':4, 'MAY':5, 'JUN':6, 'JUL':7, 'AUG':8, 'SEP':9,'OCT':10, 'NOV':11, 'DEC':12}
    return mon[val]

# %%
df["Month"] = df["Month"].apply(split_Date)

# %%
df
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail Price  Month  Year
# 0           Food  JAN-2001          24.0      1  2001
# ...

# %%
columns_to_be_removed = ["Category","Date"]

# %%
df.drop(columns_to_be_removed,axis = 1,inplace= True)

# %%
df_test = df[df["Retail Price"].isnull()==True]

# %%
df_train = df.dropna()
df_train
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#          Retail Price  Month  Year
# 0                24.0      1  2001
# 1                26.0      1  2001
# ...

# %%
sns.barplot(x="Unit",y="Retail Price",data=df)
# Out:
# <AxesSubplot:xlabel='Unit', ylabel='Retail Price'>

# %%
import statsmodels.api as s
x=df[['Year']]
y=df['Retail Price']

# %%
x
# Out:
#          Year
# 0        2001
# 1        2001
# 2        2001
# 3        2001
# 4        2001
# ...       ...
# 1147441  2021
# 1147442  2021
# 1147443  2021
# 1147444  2021
# 1147445  2021
#
# [1147436 rows x 1 columns]

# %%
y
# Out:
# 0          24.0
# 1          26.0
# 2          25.5
# 3           0.0
# 4           0.0
#            ...
# 1147441     0.0
# 1147442     0.0
# 1147443     0.0
# 1147444    20.0
# 1147445     0.0
# Name: Retail Price, Length: 1147436, dtype: float64

# %%
np.asarray(df)
# Out:
# array([['Andhra Pradesh', 'Chittoor', 'Moong', ..., 24.0, 1, '2001'],
#        ['Andhra Pradesh', 'Guntur', 'Moong', ..., 26.0, 1, '2001'],
#        ['Andhra Pradesh', 'Kurnool', 'Moong', ..., 25.5, 1, '2001'],
#        ...,
#        ['West Bengal', 'Kolkata', 'Wheat', ..., 0.0, 3, '2021'],
#        ['West Bengal', 'Malda', 'Wheat', ..., 20.0, 3, '2021'],
#        ['West Bengal', 'Malda', 'Wheat', ..., 0.0, 3, '2021']],
#       dtype=object)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([3.81747849])

# %%
model.intercept_
# Out:
# -7635.356250556446

# %%
print(model.predict([[4.0]]))
# Out:
# [-7620.08633658]

# %% [markdown]
# # model based on training and testing results:

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20)

# %%
model=LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
predictedr=model.predict(xtest)
predictedr
# Out:
# array([75.83369499, 79.64289155, 72.02449843, ..., 45.3601225 ,
#        49.16931906, 60.59690875])

# %%
#overfitting and underfitting situation
model.score(xtrain,ytrain)*100
# Out:
# 3.9208276855032698

# %%
model.score(xtest,ytest)*100
# Out:
# 3.8567129782605014

# %%
#evaluation process / accuracy score or standard error
#linear : residual =actual value-predicted value

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(ytest,predictedr))
# Out:
# 49.059292638002745

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(ytest,predictedr))
# Out:
# 12636.435301961645

# %%
import math
print(math.sqrt(mean_squared_error(ytest,predictedr)))
# Out:
# 112.4119001794812

# %%
sns.barplot(x="Year",y="Retail Price",data=df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Retail Price'>

# %% [markdown]
# # Q.1)what is the maximum retail price?

# %%
df["Retail Price"].max()
# Out:
# 20045.0

# %% [markdown]
# # Q.2)what is the minimum retail price?

# %%
df["Retail Price"].min()
# Out:
# 0.0
